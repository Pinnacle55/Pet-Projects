# %%
import scrapy
import pandas as pd
from scrapy.crawler import CrawlerProcess

# Dictionary of lists to store our results. Probably a better way to do this.
features = ['date', 'seen', 'score', 'helpful', 'review']
reviews = {x:list() for x in features}

class MALCrawler(scrapy.Spider):
    name = 'MAL Crawler'
    def start_requests(self):
        # List of urls to scrape
        #urls = ['https://myanimelist.net/anime/20/Naruto/reviews?p=' + str(x) for x in range(1,8)]
        urls = ['https://myanimelist.net/anime/34798/Yuru_Camp△/reviews?p=' + str(x) for x in range(1,9)]
        for url in urls:
            yield scrapy.Request(url = url, callback = self.parse)
    
    # What we're gonna parse from each url
    def parse(self, response):
        # Get dates
        for date in response.xpath('//div[@class="mb8"]/div[1]/text()').extract():
            reviews['date'].append(date)
        
        # Get episodes seen
        for seen in response.xpath('//div[@class="mb8"]/div[2]/text()').extract():
            reviews['seen'].append(seen.strip())
            
        # Get score
        for score in response.xpath('//div[@class="mb8"]/div[3]/text()[2]').extract():
            reviews['score'].append(score[1:].strip())
            
        # Get helpful
        for helpful in response.xpath('//span[contains(@id,"rhelp")]/text()').extract():
            reviews['helpful'].append(helpful)
            
        # Get reviews
        for element in response.xpath('//div[@class="spaceit textReadability word-break pt8 mt8"]'):
            # Grab all instances of text (will be several having been broken up by br tags)
            text = [x.strip() for x in element.xpath('./text()').extract()]
            # Converts text into a string when you join it. 
            text_preview = " ".join(text)

            # So the above gets the previewed text. We now want the text body.
            text = [x.strip() for x in element.xpath('./span[contains(@id,review)]/text()').extract()]
            text_body = " ".join(text)

            # We now want to combine the preview and body together into a list
            text_review = text_preview + ' ' + text_body
            reviews['review'].append(text_review)
        
process = CrawlerProcess()

process.crawl(MALCrawler)

process.start()
# Out:
# 2021-01-15 14:36:03 [scrapy.utils.log] INFO: Scrapy 2.4.1 started (bot: scrapybot)
# 2021-01-15 14:36:03 [scrapy.utils.log] INFO: Versions: lxml 4.5.0.0, libxml2 2.9.9, cssselect 1.1.0, parsel 1.5.2, w3lib 1.21.0, Twisted 20.3.0, Python 3.7.6 (default, Jan  8 2020, 20:23:39) [MSC v.1916 64 bit (AMD64)], pyOpenSSL 19.1.0 (OpenSSL 1.1.1d  10 Sep 2019), cryptography 2.8, Platform Windows-7-6.1.7601-SP1
# 2021-01-15 14:36:03 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.selectreactor.SelectReactor
# 2021-01-15 14:36:03 [scrapy.crawler] INFO: Overridden settings:
# {}
# 2021-01-15 14:36:03 [scrapy.extensions.telnet] INFO: Telnet Password: c5562cf66d6a2f58
# 2021-01-15 14:36:03 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.logstats.LogStats']
# 2021-01-15 14:36:04 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2021-01-15 14:36:04 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2021-01-15 14:36:04 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2021-01-15 14:36:04 [scrapy.core.engine] INFO: Spider opened
# 2021-01-15 14:36:04 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2021-01-15 14:36:04 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# 2021-01-15 14:36:05 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://myanimelist.net/anime/34798/Yuru_Camp%E2%96%B3/reviews?p=8> (referer: None)
# 2021-01-15 14:36:05 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://myanimelist.net/anime/34798/Yuru_Camp%E2%96%B3/reviews?p=4> (referer: None)
# 2021-01-15 14:36:05 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://myanimelist.net/anime/34798/Yuru_Camp%E2%96%B3/reviews?p=2> (referer: None)
# 2021-01-15 14:36:05 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://myanimelist.net/anime/34798/Yuru_Camp%E2%96%B3/reviews?p=1> (referer: None)
# 2021-01-15 14:36:05 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://myanimelist.net/anime/34798/Yuru_Camp%E2%96%B3/reviews?p=7> (referer: None)
# 2021-01-15 14:36:05 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://myanimelist.net/anime/34798/Yuru_Camp%E2%96%B3/reviews?p=3> (referer: None)
# 2021-01-15 14:36:05 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://myanimelist.net/anime/34798/Yuru_Camp%E2%96%B3/reviews?p=6> (referer: None)
# 2021-01-15 14:36:05 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://myanimelist.net/anime/34798/Yuru_Camp%E2%96%B3/reviews?p=5> (referer: None)
# 2021-01-15 14:36:05 [scrapy.core.engine] INFO: Closing spider (finished)
# 2021-01-15 14:36:06 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 2056,
#  'downloader/request_count': 8,
#  'downloader/request_method_count/GET': 8,
#  'downloader/response_bytes': 1352999,
#  'downloader/response_count': 8,
#  'downloader/response_status_count/200': 8,
#  'elapsed_time_seconds': 1.422082,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2021, 1, 15, 6, 36, 6, 1312),
#  'log_count/DEBUG': 8,
#  'log_count/INFO': 10,
#  'response_received_count': 8,
#  'scheduler/dequeued': 8,
#  'scheduler/dequeued/memory': 8,
#  'scheduler/enqueued': 8,
#  'scheduler/enqueued/memory': 8,
#  'start_time': datetime.datetime(2021, 1, 15, 6, 36, 4, 579230)}
# 2021-01-15 14:36:06 [scrapy.core.engine] INFO: Spider closed (finished)

# %%
# Looks good so far!
df = pd.DataFrame(reviews)

# #df.to_csv('Datacamp CSV/Naruto_Reviews.csv')
# df['helpful'] = df['helpful'].astype(int)
# df.sort_values(['helpful'], ascending = False)

df.to_csv('Datacamp CSV/YuruCamp_Reviews.csv')

# %%
# Looks good so far!
df = pd.DataFrame(reviews)

#df.to_csv('Datacamp CSV/Naruto_Reviews.csv')
df
# Out:
#             date                      seen score helpful  \
# 0   Apr 27, 2008  220 of 220 episodes seen     7    1060
# 1   Jun 25, 2008  220 of 220 episodes seen     7     730
# 2    Dec 3, 2011  220 of 220 episodes seen    10     344
# 3   Apr 30, 2011  220 of 220 episodes seen     8     321
# 4   Dec 18, 2014  220 of 220 episodes seen     4     227
# 5   Jun 26, 2010  180 of 220 episodes seen    10     203
# 6   Dec 19, 2008  220 of 220 episodes seen     1     166
# 7    Jun 8, 2009   40 of 220 episodes seen     3     140
# 8    Sep 3, 2008  220 of 220 episodes seen     9     116
# 9    Feb 5, 2009  220 of 220 episodes seen    10     110
# 10  Jan 11, 2009  220 of 220 episodes seen     8     104
# 11   Mar 4, 2008    1 of 220 episodes seen     1      89
# 12   Feb 9, 2007  220 of 220 episodes seen     7      75
# 13  Jan 10, 2009  120 of 220 episodes seen     9      69
# 14   Apr 8, 2008  220 of 220 episodes seen     5      69
# 15  Oct 30, 2007   60 of 220 episodes seen     1      68
# 16   Apr 5, 2012  220 of 220 episodes seen    10      66
# 17   May 5, 2008  220 of 220 episodes seen     7      61
# 18  Jun 17, 2008  120 of 220 episodes seen     4      58
# 19  Jan 25, 2012  220 of 220 episodes seen     9      55
# 20   Apr 2, 2010  220 of 220 episodes seen     9      50
# 21   Apr 3, 2012    4 of 220 episodes seen     1      50
# 22   Oct 4, 2008  220 of 220 episodes seen     2      47
# 23  Sep 17, 2008  220 of 220 episodes seen     8      46
# 24   Feb 8, 2013  220 of 220 episodes seen     8      43
# 25  Nov 12, 2008  199 of 220 episodes seen     9      40
# 26  May 19, 2014  180 of 220 episodes seen     8      40
# 27  Aug 10, 2010  150 of 220 episodes seen     1      35
# 28  Jan 11, 2009  220 of 220 episodes seen     4      34
# 29   Jan 8, 2009  220 of 220 episodes seen     1      33
# 30  Feb 10, 2008  204 of 220 episodes seen    10      32
# 31  Apr 17, 2016  220 of 220 episodes seen     1      32
# 32  Aug 27, 2014  220 of 220 episodes seen     6      32
# 33  Apr 16, 2010  220 of 220 episodes seen     6      31
# 34  Jul 22, 2010   43 of 220 episodes seen     1      31
# 35  Jan 27, 2009    2 of 220 episodes seen     4      28
# 36  Jul 19, 2012  220 of 220 episodes seen     9      27
# 37  Aug 13, 2007  135 of 220 episodes seen     7      27
# 38  Sep 17, 2009  220 of 220 episodes seen     9      27
# 39  Jul 20, 2007  220 of 220 episodes seen     7      27
#
#                                                review
# 0    To be honest, Naruto is the most overhyped sh...
# 1    I began to browse through the reviews of Naru...
# 2    Naruto, yes Naruto. One of the series that ha...
# 3    I'm sure most, if not all, the people who end...
# 4    I would like to start this review off by sayi...
# 5    I've heard a lot of people call this the most...
# 6    ok so I've seen like 200+ series and i have t...
# 7    Proof that I will watch just about anything, ...
# 8    Having watched many different series of anime...
# 9    Naruto is a hit or miss show. You love it, or...
# 10   Naruto, a lot of the new generations first fa...
# 11   Naruto is the typical Shounen anime. Despite ...
# 12   The mighty roar of a Kyubei vibrated througho...
# 13   Naruto was the first anime I ever watched. An...
# 14   Story: Naruto is a fairly decent anime that m...
# 15   This has to be one of the worst anime series ...
# 16   Naruto, who doesn't know about it? It's a wil...
# 17   First to say: I decided to write a review for...
# 18   Wow... I look back and realize how painfully ...
# 19   Hm... Naruto as a series is a difficult one t...
# 20   I laughed, i cried and i was excited. In othe...
# 21   Naruto is a gateway anime of the worst kind. ...
# 22   Naruto has to be the most over rated anime in...
# 23   Naruto is a hit and miss with some people. Yo...
# 24   Okay an honest review here truthfully this is...
# 25   Although Naruto is sometimes overexaggerated ...
# 26   Naruto (not Naruto Shippuden) is awesome. It ...
# 27   As a big anime fan, i watched many different ...
# 28   NARUTARDS BEWARE  Let me start off by saying ...
# 29   I used to think that naruto was an ok show. B...
# 30   Okay. Well, at first, I saw my brother watchi...
# 31   Naruto (also referred to as "Ninja Brokeback ...
# 32   Overview:  Naruto has been going strong for 1...
# 33   I believe that Naruto is in fact, if not the ...
# 34   I forced my way though around 43 episodes bef...
# 35   This is one of the most over rated animes eve...
# 36   Alright, so let me start off by saying, boy, ...
# 37   Characters/Development Although the beginning...
# 38   Many first-timers love this anime and some ex...
# 39   First off: The fillers are definately not wor...

# %%
# Test trying to look at MAL for anime reviews

import requests
import pandas as pd
from scrapy import Selector

# Main structure of URL is relatively easy, we can loop from p=1 to p=N
url = 'https://myanimelist.net/anime/20/Naruto/reviews?p=1'

html = requests.get(url).content

sel = Selector(text = html)

# %%
# We want certain information from each review page. 
# 1. Overall score
# 2. Number of episodes seen
# 3. Actual Review
# 4. Date of Review
# 5. No. of people who found it useful.

# How to identify each within the html block?

# Get the date of each review on the page
# Each date, episodes seen, and score are contained within the mb8 class. 
# Looking at the pattern, div[1] is the date, div[2] is the number of episodes seen, and 
# div[4] is the actual score

reviews = {}

# All dates
reviews['date'] = sel.xpath('//div[@class="mb8"]/div[1]/text()').extract()

# All episodes seen
reviews['seen'] = [x.strip() for x in sel.xpath('//div[@class="mb8"]/div[2]/text()').extract()]

# All scores
reviews['score'] = [x[1:].strip() for x in sel.xpath('//div[@class="mb8"]/div[3]/text()[2]').extract()]

# Let's try and find out how to get the number of people seen
# It seems that it's contained within a span tag that contains an id with rhelp'reviewno.'
reviews['help'] = sel.xpath('//span[contains(@id,"rhelp")]/text()').extract()

# Finally, lets figure out how to get the actual review.
# This is where it gets kind of weird. It seems that reviews are contained within two parts. 
# One within a div tag with @class="spaceit...etc.'' and a span tag with id = review'reviewno.'
# We need to get both parts

# Another problem is that there are a ton of <br> tags, which really fuck up the text because
# they separate them into different instances of text each time. We'll need to 
# make a loop to attach them again
review = list()

for element in sel.xpath('//div[@class="spaceit textReadability word-break pt8 mt8"]'):
    # Grab all instances of text (will be several having been broken up by br tags)
    text = [x.strip() for x in element.xpath('./text()').extract()]
    # Converts text into a string when you join it. 
    text_preview = " ".join(text)
    
    # So the above gets the previewed text. We now want the text body.
    text = [x.strip() for x in element.xpath('./span[contains(@id,review)]/text()').extract()]
    text_body = " ".join(text)
    
    # We now want to combine the preview and body together into a list
    review.append(text_preview + ' ' + text_body)

# Add it to our dictionary
reviews['review'] = review

# %%
# Very cool, we've managed to collect 20 reviews by scraping the MAL site for Naruto!
# We can now attempt to create a scrapy spider that will attempt to grab around 400 reviews 
# for Naruto.
df = pd.DataFrame(reviews)
